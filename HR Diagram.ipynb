# %%
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d08b545e-c2b6-4fd7-828c-b4d25fbc0a50">Loading BokehJS ...</span>
#     </div>

# %%
import hr
hr.visual.diagram_compare('berkeley20', 'ngc2849')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a8061466-a3c8-4d28-8095-90ba5719397f"></div>
# </div>

# %%
lines = None
with open('data/berkeley20-durgapal.dat') as f:
    lines = f.readlines()

# %%
import re
pattern = re.compile("^\s+|\s* \s*|\s+$")
for l in lines:
    values = [v for v in pattern.split(l) if v]
values[3]
# Out:
# '16.589'
